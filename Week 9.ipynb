# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Auto Regessive Moving Averages Model (ARMA)
import statsmodels as sm
from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.arima.model import ARIMA
import seaborn as sns
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
import statsmodels.stats.diagnostic as df

# %%
data = pd.read_csv('marathon.csv',index_col=0,parse_dates=True)
data.head()
# Out:
#               marathon
# Year
# 1897-01-01  175.166667
# 1898-01-01  162.000000
# 1899-01-01  174.633333
# 1900-01-01  159.733333
# 1901-01-01  149.383333

# %%
data.index.freq = 'YS'
data.index.freq
# Out:
# <YearBegin: month=1>

# %%
plot_acf(data)

# %%
plot_pacf(data)
# Out:
# C:\Users\reece\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
data.plot() # not stationary
# Out:
# <Axes: xlabel='Year'>

# %%
model_ar2 = ARIMA(data,order=(2,0,2))
fit_ar2 = model_ar2.fit()
# Out:
# C:\Users\reece\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\reece\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\reece\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)

# %%
Fcast_ar2 = fit_ar2.predict(len(data),len(data)+24)
Fcast_ar2
# Out:
# 2017-01-01    131.137374
# 2018-01-01    130.594393
# 2019-01-01    131.107918
# 2020-01-01    130.981463
# 2021-01-01    131.240526
# 2022-01-01    131.265225
# 2023-01-01    131.430274
# 2024-01-01    131.509178
# 2025-01-01    131.638857
# 2026-01-01    131.736554
# 2027-01-01    131.852305
# 2028-01-01    131.955873
# 2029-01-01    132.065544
# 2030-01-01    132.170275
# 2031-01-01    132.276750
# 2032-01-01    132.380937
# 2033-01-01    132.485283
# 2034-01-01    132.588317
# 2035-01-01    132.690938
# 2036-01-01    132.792610
# 2037-01-01    132.893667
# 2038-01-01    132.993915
# 2039-01-01    133.093480
# 2040-01-01    133.192294
# 2041-01-01    133.290407
# Freq: AS-JAN, Name: predicted_mean, dtype: float64

# %%
data.plot(label='Actual')
Fcast_ar2.plot(label='ARIMA Plot')
plt.show()

# %%
model_ar3 = ARIMA(data,order=(2,0,0))
fit_ar3 = model_ar3.fit()
Fcast_ar3 = fit_ar3.predict(len(data),len(data)+24)
Fcast_ar3
# Out:
# C:\Users\reece\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\reece\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\reece\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# 2017-01-01    132.476721
# 2018-01-01    133.475113
# 2019-01-01    133.976920
# 2020-01-01    134.604711
# 2021-01-01    135.141176
# 2022-01-01    135.665891
# 2023-01-01    136.153269
# 2024-01-01    136.614770
# 2025-01-01    137.048610
# 2026-01-01    137.457559
# 2027-01-01    137.842650
# 2028-01-01    138.205414
# 2029-01-01    138.547097
# ...

# %%
data.plot(label='Actual')
Fcast_ar2.plot(label='ARIMA Plot')
Fcast_ar3.plot(label='ARIMA Plot 2')
plt.show()

# %%
model_ar4 = ARIMA(data,order=(0,1,0))
fit_ar4 = model_ar4.fit()
Fcast_ar4 = fit_ar4.predict(len(data),len(data)+24)
Fcast_ar4
# Out:
# C:\Users\reece\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\reece\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\reece\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# 2017-01-01    132.733333
# 2018-01-01    132.733333
# 2019-01-01    132.733333
# 2020-01-01    132.733333
# 2021-01-01    132.733333
# 2022-01-01    132.733333
# 2023-01-01    132.733333
# 2024-01-01    132.733333
# 2025-01-01    132.733333
# 2026-01-01    132.733333
# 2027-01-01    132.733333
# 2028-01-01    132.733333
# 2029-01-01    132.733333
# ...

# %%
data.plot(label='Actual')
Fcast_ar2.plot(label='ARIMA Plot')
Fcast_ar3.plot(label='ARIMA Plot 2')
Fcast_ar4.plot(label='ARIMA PLOT 3')
plt.show()

# %%
model_ar5 = ARIMA(data,order=(2,1,0))
fit_ar5 = model_ar5.fit()
Fcast_ar5 = fit_ar5.predict(len(data),len(data)+24)
Fcast_ar5
# Out:
# C:\Users\reece\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\reece\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\reece\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# 2017-01-01    130.599694
# 2018-01-01    130.169121
# 2019-01-01    131.364517
# 2020-01-01    130.925003
# 2021-01-01    130.616667
# 2022-01-01    130.979514
# 2023-01-01    130.926600
# 2024-01-01    130.790275
# 2025-01-01    130.886625
# 2026-01-01    130.897247
# 2027-01-01    130.847949
# 2028-01-01    130.869307
# 2029-01-01    130.880307
# ...

# %%
data.plot(label='Actual')
Fcast_ar2.plot(label='ARIMA Plot')
Fcast_ar3.plot(label='ARIMA Plot 2')
Fcast_ar4.plot(label='ARIMA PLOT 3')
Fcast_ar5.plot(label='ARIMA Plot 4')
plt.show()

# %%
def tsplot(y, lags=None, figsize=(10, 8), style='fivethirtyeight'):
    import pandas as pd
    import numpy as np
    import statsmodels.tsa.api as smt
    from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
    import statsmodels.api as sm
    import scipy.stats as scs
    import statsmodels.stats as sms 
    import matplotlib.pyplot as plt

    if not isinstance(y, pd.Series):
        y = pd.Series(y)
    with plt.style.context(style):    
        fig = plt.figure(figsize=figsize)
        layout = (3, 2)
        ts_ax = plt.subplot2grid(layout, (0, 0), colspan=2)
        acf_ax = plt.subplot2grid(layout, (1, 0))
        pacf_ax = plt.subplot2grid(layout, (1, 1))
        qq_ax = plt.subplot2grid(layout, (2, 0))
        pp_ax = plt.subplot2grid(layout, (2, 1))
        
        y.plot(ax=ts_ax)
        ts_ax.set_title('Time Series Analysis Plots')
        smt.graphics.plot_acf(y, lags=lags, ax=acf_ax, alpha=0.05)
        smt.graphics.plot_pacf(y, lags=lags, ax=pacf_ax, alpha=0.05)
        sm.qqplot(y, line='s', ax=qq_ax)
        qq_ax.set_title('QQ Plot')        
        scs.probplot(y, sparams=(y.mean(), y.std()), plot=pp_ax)
        plt.tight_layout()
    return

# %%
tsplot(data['marathon'])
# Out:
# C:\Users\reece\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
# SARIMA 
df = pd.read_csv('milk.csv',index_col=0,parse_dates=True)
df
# Out:
#             milk
# index
# 1962-01-01   589
# 1962-02-01   561
# 1962-03-01   640
# 1962-04-01   656
# 1962-05-01   727
# ...          ...
# 1975-08-01   858
# 1975-09-01   817
# 1975-10-01   827
# 1975-11-01   797
# 1975-12-01   843
#
# [168 rows x 1 columns]

# %%
df.index.freq = 'MS'

# %%
df.index.freq

# %%
df.plot()
# Out:
# <Axes: xlabel='index'>

# %%
df.fillna(0)
# Out:
#             milk
# index
# 1962-01-01   589
# 1962-02-01   561
# 1962-03-01   640
# 1962-04-01   656
# 1962-05-01   727
# ...          ...
# 1975-08-01   858
# 1975-09-01   817
# 1975-10-01   827
# 1975-11-01   797
# 1975-12-01   843
#
# [168 rows x 1 columns]

# %%
y = df['milk']

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
y.plot()
# Out:
# <Axes: xlabel='index'>

# %%
# figure out parameters 
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decom = seasonal_decompose(y,period=12)
decom.plot()
plt.show()

# %%
df['month'] = pd.to_datetime(df.index).month
df['year'] = pd.to_datetime(df.index).year

# %%
df
# Out:
#             milk  month  year
# index
# 1962-01-01   589      1  1962
# 1962-02-01   561      2  1962
# 1962-03-01   640      3  1962
# 1962-04-01   656      4  1962
# 1962-05-01   727      5  1962
# ...          ...    ...   ...
# 1975-08-01   858      8  1975
# 1975-09-01   817      9  1975
# 1975-10-01   827     10  1975
# 1975-11-01   797     11  1975
# 1975-12-01   843     12  1975
#
# [168 rows x 3 columns]

# %%
sns.lineplot(x='month',y='milk',hue='year',data=df)
# Out:
# <Axes: xlabel='month', ylabel='milk'>

# %%
plot_acf(y,lags=50)

# %%
plot_pacf(y,lags=50)
# Out:
# C:\Users\reece\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
from statsmodels.tsa.stattools import adfuller # confirms stationary

# %%
dftest = adfuller(y)

# %%
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','# of Lags','# of Obs'])
for key, value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Test Statistic           -1.303812
# p-value                   0.627427
# # of Lags                13.000000
# # of Obs                154.000000
# Critical Value (1%)      -3.473543
# Critical Value (5%)      -2.880498
# Critical Value (10%)     -2.576878
# dtype: float64

# %%
y_diff = y.diff().diff(12).dropna()

# %%
y_diff.plot()
# Out:
# <Axes: xlabel='index'>

# %%
dftest = adfuller(y_diff)

# %%
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','# of Lags','# of Obs'])
for key, value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Test Statistic           -5.038002
# p-value                   0.000019
# # of Lags                11.000000
# # of Obs                143.000000
# Critical Value (1%)      -3.476927
# Critical Value (5%)      -2.881973
# Critical Value (10%)     -2.577665
# dtype: float64

# %%
plot_acf(y_diff,lags=50)

# %%
plot_pacf(y_diff,lags=50)
# Out:
# C:\Users\reece\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
# split data

# %%
train_size = int(len(y)*0.85)
train = y[1:train_size]
test = y[train_size:]

# %%
train.plot(label='Train')
test.plot(label='Test')
plt.show()

# %%
import pmdarima as pm

# %%
model = pm.auto_arima(y)
model
# Out:
# ARIMA(order=(2, 1, 5), scoring_args={}, suppress_warnings=True,
#       with_intercept=False)

# %%
model = pm.auto_arima(y, d=1, D=1,
                      m=12, trend='c', seasonal=True, 
                      start_p=0, start_q=0, max_order=6, test='adf',
                      stepwise=True, trace=True)
model
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(1,1,1)[12]             : AIC=1076.128, Time=0.18 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=1121.939, Time=0.02 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=1083.569, Time=0.15 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=1068.286, Time=0.15 sec
#  ARIMA(0,1,1)(0,1,0)[12]             : AIC=1116.950, Time=0.08 sec
#  ARIMA(0,1,1)(1,1,1)[12]             : AIC=1070.017, Time=0.23 sec
#  ARIMA(0,1,1)(0,1,2)[12]             : AIC=1069.963, Time=0.41 sec
#  ARIMA(0,1,1)(1,1,0)[12]             : AIC=1084.109, Time=0.16 sec
#  ARIMA(0,1,1)(1,1,2)[12]             : AIC=inf, Time=1.02 sec
#  ARIMA(0,1,0)(0,1,1)[12]             : AIC=1074.277, Time=0.16 sec
#  ARIMA(1,1,1)(0,1,1)[12]             : AIC=1070.056, Time=0.25 sec
#  ARIMA(0,1,2)(0,1,1)[12]             : AIC=1069.791, Time=0.30 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=1068.200, Time=0.14 sec
# ...

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
SARIMAX(y)

# %%
model.fit(y)
# Out:
# ARIMA(order=(1, 1, 0), scoring_args={}, seasonal_order=(0, 1, 1, 12),
#       suppress_warnings=True, trend='c', with_intercept=False)

# %%
model.fit(y).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ...
# Dep. Variable:                                    y   No. Observations:                  168
# Model:             SARIMAX(1, 1, 0)x(0, 1, [1], 12)   Log Likelihood                -530.100
# Date:                              Fri, 28 Jul 2023   AIC                           1068.200
# Time:                                      12:16:46   BIC                           1080.374
# Sample:                                  01-01-1962   HQIC                          1073.145
#                                        - 12-01-1975
# Covariance Type:                                opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -0.0211      0.287     -0.074      0.941      -0.584       0.542
# ...

# %%
model = SARIMAX(train,order=(1,0,1),seasonal_order=(0,1,1,12))
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ...
# Dep. Variable:                               milk   No. Observations:                  141
# Model:             SARIMAX(1, 0, 1)x(0, 1, 1, 12)   Log Likelihood                -446.477
# Date:                            Fri, 28 Jul 2023   AIC                            900.954
# Time:                                    12:20:12   BIC                            912.393
# Sample:                                02-01-1962   HQIC                           905.602
#                                      - 10-01-1973
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9936      0.008    125.238      0.000       0.978       1.009
# ma.L1         -0.2762      0.085     -3.235      0.001      -0.444      -0.109
# ...

# %%
results.plot_diagnostics()
plt.show()

# %%
forecast_object = results.get_forecast(steps=len(test))      # note, here SARIMA has get_prediction() ,ETS uses get_prediction()
mean = forecast_object.predicted_mean
conf_int = forecast_object.conf_int()
dates = mean.index

# %%
plt.figure(figsize=(16,8))
plt.plot(train.index, train, label='Training')
plt.plot(test.index, test, label='Test')
plt.plot(dates, mean, label='predicted test')
plt.fill_between(dates, conf_int.iloc[:,0], conf_int.iloc[:,1], alpha=0.5)
plt.legend()
plt.show()

# %%
def accuracy(y_test,y_pred):
    from statsmodels.tools.eval_measures import rmse, rmspe, meanabs, mse
    from sktime.performance_metrics.forecasting import mean_absolute_percentage_error  
    from sklearn.metrics import r2_score
    R_sq= r2_score(y_test,y_pred)
    RMSE = rmse(y_test,y_pred)
    RMSPE = rmspe(y_test,y_pred)
    MAE = meanabs(y_test,y_pred)
    MSE =  mse(y_test,y_pred)
    MAPE = mean_absolute_percentage_error(y_test,y_pred)    
    print('R-SQ : %f' % R_sq, ' RMSE : %f' % RMSE, ' RMSPE : %f' % RMSPE, ' MAE : %f' % MAE, ' MSE : %f' % MSE , ' MAPE : %f' % MAPE)
# Out:
# R-SQ : 0.913138  RMSE : 17.731794  RMSPE : 0.208639  MAE : 15.132845  MSE : 314.416527  MAPE : 0.017736

# %%
forecast_future=results.get_forecast(steps=60)

# now make the prediction

pred_f = results.get_forecast(steps=60)
pred_ci = pred_f.conf_int()
ax = train.plot(label='Train', figsize=(14, 7))
test.plot(ax=ax, label='Test')
pred_f.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Month')
ax.set_ylabel('Monthly Milk Production')
plt.legend()
plt.show()

# Obtain the forecast data

forecast = forecast_future.summary_frame(alpha=0.05)
forecast.index.name ='Month'

full_data_with_forecast = df.join(forecast)
full_data_with_forecast.to_csv('forecast_output.csv')   # Store the Forecast Outputs

# %%
# Sarima with Exogenous varibles SarimaX

# %%
from statsmodels.tsa.api import VAR
from statsmodels.tsa.statespace.sarimax import SARIMAX
from random import random

# %%
df = pd.read_csv('uschange.csv',parse_dates=True,index_col=0)
df
# Out:
#             Consumption    Income  Production   Savings  Unemployment
# Quarter
# 1970-03-31     0.615986  0.972261   -2.452700  4.810312           0.9
# 1970-06-30     0.460376  1.169085   -0.551525  7.287992           0.5
# 1970-09-30     0.876791  1.553271   -0.358708  7.289013           0.5
# 1970-12-31    -0.274245 -0.255272   -2.185455  0.985230           0.7
# 1971-03-31     1.897371  1.987154    1.909734  3.657771          -0.1
# ...                 ...       ...         ...       ...           ...
# 2015-09-30     0.664970  0.801663    0.380606  3.180930          -0.3
# 2015-12-31     0.561680  0.740063   -0.845546  3.482786           0.0
# 2016-03-31     0.404682  0.519025   -0.417930  2.236534           0.0
# 2016-06-30     1.047707  0.723721   -0.203319 -2.721501          -0.1
# 2016-09-30     0.729598  0.644701    0.474918 -0.572858           0.0
#
# [187 rows x 5 columns]

# %%
df.index.freq = 'Q'

# %%
y = df['Consumption']
x = df['Income']

# %%
model = SARIMAX(y,exog=x)
fit = model.fit()
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:            Consumption   No. Observations:                  187
# Model:               SARIMAX(1, 0, 0)   Log Likelihood                -191.332
# Date:                Fri, 28 Jul 2023   AIC                            388.664
# Time:                        12:30:37   BIC                            398.357
# Sample:                    03-31-1970   HQIC                           392.592
#                          - 09-30-2016
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Income         0.1479      0.031      4.777      0.000       0.087       0.209
# ar.L1          0.6491      0.055     11.894      0.000       0.542       0.756
# sigma2         0.4518      0.041     11.073      0.000       0.372       0.532
# ...

# %%
from dateutil.relativedelta import relativedelta

# %%
date_range = pd.date_range(start=x.index[-1]+relativedelta(month=3),periods=12,freq='Q')
date_range
# Out:
# DatetimeIndex(['2016-03-31', '2016-06-30', '2016-09-30', '2016-12-31',
#                '2017-03-31', '2017-06-30', '2017-09-30', '2017-12-31',
#                '2018-03-31', '2018-06-30', '2018-09-30', '2018-12-31'],
#               dtype='datetime64[ns]', freq='Q-DEC')

# %%
X_cast =pd.Series([0.55,0.66,0.44,0.69,0.55,0.88,0.34,0.55,0.66,0.44,0.69,0.55],index=date_range)
X_cast
# Out:
# 2016-03-31    0.55
# 2016-06-30    0.66
# 2016-09-30    0.44
# 2016-12-31    0.69
# 2017-03-31    0.55
# 2017-06-30    0.88
# 2017-09-30    0.34
# 2017-12-31    0.55
# 2018-03-31    0.66
# 2018-06-30    0.44
# 2018-09-30    0.69
# 2018-12-31    0.55
# Freq: Q-DEC, dtype: float64

# %%
y
# Out:
# Quarter
# 1970-03-31    0.615986
# 1970-06-30    0.460376
# 1970-09-30    0.876791
# 1970-12-31   -0.274245
# 1971-03-31    1.897371
#                 ...
# 2015-09-30    0.664970
# 2015-12-31    0.561680
# 2016-03-31    0.404682
# 2016-06-30    1.047707
# 2016-09-30    0.729598
# Freq: Q-DEC, Name: Consumption, Length: 187, dtype: float64

# %%
y_cast = fit.predict(start=len(y),end=len(y)+11,exog=[X_cast])

# %%
y_cast
# Out:
# 2016-12-31    0.493041
# 2017-03-31    0.364858
# 2017-06-30    0.238545
# 2017-09-30    0.214664
# 2017-12-31    0.154446
# 2018-03-31    0.177620
# 2018-06-30    0.081090
# 2018-09-30    0.101351
# 2018-12-31    0.110611
# 2019-03-31    0.073513
# 2019-06-30    0.107541
# 2019-09-30    0.084912
# Freq: Q-DEC, Name: predicted_mean, dtype: float64

# %%
X_cast
# Out:
# 2016-03-31    0.55
# 2016-06-30    0.66
# 2016-09-30    0.44
# 2016-12-31    0.69
# 2017-03-31    0.55
# 2017-06-30    0.88
# 2017-09-30    0.34
# 2017-12-31    0.55
# 2018-03-31    0.66
# 2018-06-30    0.44
# 2018-09-30    0.69
# 2018-12-31    0.55
# Freq: Q-DEC, dtype: float64

# %%
forecast_object = fit.get_forecast(steps=len(X_cast), exog=X_cast)      # note, here SARIMA has get_prediction() ,ETS uses get_prediction()
mean = forecast_object.predicted_mean
conf_int = forecast_object.conf_int()
dates = mean.index


#### Now do the Plot of the Original vs. Predicted data with Prediction Intervals using statsmodel

plt.figure(figsize=(16,8))
plt.plot(y.index, y, label='Actual Consumption')
plt.plot(date_range, mean, label='Prediction')
plt.fill_between(date_range, conf_int.iloc[:,0], conf_int.iloc[:,1], alpha=0.5)
plt.legend()
plt.show()
